# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Sod.block0.out1.00000.tab  Sod.block0.out1.00015.tab
# Sod.block0.out1.00001.tab  Sod.block0.out1.00016.tab
# Sod.block0.out1.00002.tab  Sod.block0.out1.00017.tab
# Sod.block0.out1.00003.tab  Sod.block0.out1.00018.tab
# Sod.block0.out1.00004.tab  Sod.block0.out1.00019.tab
# Sod.block0.out1.00005.tab  Sod.block0.out1.00020.tab
# Sod.block0.out1.00006.tab  Sod.block0.out1.00021.tab
# Sod.block0.out1.00007.tab  Sod.block0.out1.00022.tab
# Sod.block0.out1.00008.tab  Sod.block0.out1.00023.tab
# Sod.block0.out1.00009.tab  Sod.block0.out1.00024.tab
# Sod.block0.out1.00010.tab  Sod.block0.out1.00025.tab
# Sod.block0.out1.00011.tab  Sod.hst
# Sod.block0.out1.00012.tab  athinput.bw
# Sod.block0.out1.00013.tab  athinput.sod
# Sod.block0.out1.00014.tab  make_plot.ipynb

# %%
df = pd.read_fwf('Sod.block0.out1.00000.tab',skiprows=1)
df.set_index("# i").head(20)
# Out:
#           x1v  rho  press  vel1  vel2  vel3
# # i
# 2   -0.498047  1.0    1.0   0.0   0.0   0.0
# 3   -0.494141  1.0    1.0   0.0   0.0   0.0
# 4   -0.490234  1.0    1.0   0.0   0.0   0.0
# 5   -0.486328  1.0    1.0   0.0   0.0   0.0
# 6   -0.482422  1.0    1.0   0.0   0.0   0.0
# 7   -0.478516  1.0    1.0   0.0   0.0   0.0
# 8   -0.474609  1.0    1.0   0.0   0.0   0.0
# 9   -0.470703  1.0    1.0   0.0   0.0   0.0
# 10  -0.466797  1.0    1.0   0.0   0.0   0.0
# 11  -0.462891  1.0    1.0   0.0   0.0   0.0
# 12  -0.458984  1.0    1.0   0.0   0.0   0.0
# 13  -0.455078  1.0    1.0   0.0   0.0   0.0
# 14  -0.451172  1.0    1.0   0.0   0.0   0.0
# 15  -0.447266  1.0    1.0   0.0   0.0   0.0
# 16  -0.443359  1.0    1.0   0.0   0.0   0.0
# 17  -0.439453  1.0    1.0   0.0   0.0   0.0
# 18  -0.435547  1.0    1.0   0.0   0.0   0.0
# 19  -0.431641  1.0    1.0   0.0   0.0   0.0
# 20  -0.427734  1.0    1.0   0.0   0.0   0.0
# 21  -0.423828  1.0    1.0   0.0   0.0   0.0

# %%
df.plot(x='x1v', y='rho')
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Sod.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.rho, 'b', linewidth = 3); ax1.set_title('t=0') 
ax1.set_ylabel('Density', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00008.tab',skiprows=1)
ax2.plot(df.x1v, df.rho, 'b', linewidth = 3); ax2.set_title('t=8')
ax2.set_ylabel('Density', fontsize=12)


df = pd.read_fwf('Sod.block0.out1.00016.tab',skiprows=1)
ax3.plot(df.x1v, df.rho, 'b', linewidth = 3); ax3.set_title('t=16')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Density', fontsize=12)


df = pd.read_fwf('Sod.block0.out1.00024.tab',skiprows=1)
ax4.plot(df.x1v, df.rho, 'b', linewidth = 3); ax4.set_title('t=24')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Density', fontsize=12)

plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Sod.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.press, 'g', linewidth = 3); ax1.set_title('t=0'); 
ax1.set_ylabel('Pressure', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00008.tab',skiprows=1)
ax2.plot(df.x1v, df.press, 'g', linewidth = 3); ax2.set_title('t=8')
ax2.set_ylabel('Pressure', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00016.tab',skiprows=1)
ax3.plot(df.x1v, df.press, 'g', linewidth = 3); ax3.set_title('t=16')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Pressure', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00024.tab',skiprows=1)
ax4.plot(df.x1v, df.press, 'g', linewidth = 3); ax4.set_title('t=24')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Pressure', fontsize=12)

plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Sod.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax1.set_title('t=0'); ax1.set_ylabel('density')
ax1.set_ylabel('Velocity', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00008.tab',skiprows=1)
ax2.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax2.set_title('t=8')
ax2.set_ylabel('Velocity', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00016.tab',skiprows=1)
ax3.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax3.set_title('t=16')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Velocity', fontsize=12)

df = pd.read_fwf('Sod.block0.out1.00024.tab',skiprows=1)
ax4.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax4.set_title('t=24')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Velocity', fontsize=12)

plt.show()

# %%
ls
# Out:
# Brio-Wu.block0.out1.00000.tab  Brio-Wu.block0.out1.00036.tab
# Brio-Wu.block0.out1.00001.tab  Brio-Wu.block0.out1.00037.tab
# Brio-Wu.block0.out1.00002.tab  Brio-Wu.block0.out1.00038.tab
# Brio-Wu.block0.out1.00003.tab  Brio-Wu.block0.out1.00039.tab
# Brio-Wu.block0.out1.00004.tab  Brio-Wu.block0.out1.00040.tab
# Brio-Wu.block0.out1.00005.tab  Brio-Wu.hst
# Brio-Wu.block0.out1.00006.tab  Sod.block0.out1.00000.tab
# Brio-Wu.block0.out1.00007.tab  Sod.block0.out1.00001.tab
# Brio-Wu.block0.out1.00008.tab  Sod.block0.out1.00002.tab
# Brio-Wu.block0.out1.00009.tab  Sod.block0.out1.00003.tab
# Brio-Wu.block0.out1.00010.tab  Sod.block0.out1.00004.tab
# Brio-Wu.block0.out1.00011.tab  Sod.block0.out1.00005.tab
# Brio-Wu.block0.out1.00012.tab  Sod.block0.out1.00006.tab
# Brio-Wu.block0.out1.00013.tab  Sod.block0.out1.00007.tab
# Brio-Wu.block0.out1.00014.tab  Sod.block0.out1.00008.tab
# Brio-Wu.block0.out1.00015.tab  Sod.block0.out1.00009.tab
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Brio-Wu.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.rho, 'b', linewidth = 3); ax1.set_title('t=0') 
ax1.set_ylabel('Density', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00010.tab',skiprows=1)
ax2.plot(df.x1v, df.rho, 'b', linewidth = 3); ax2.set_title('t=10')
ax2.set_ylabel('Density', fontsize=12)


df = pd.read_fwf('Brio-Wu.block0.out1.00020.tab',skiprows=1)
ax3.plot(df.x1v, df.rho, 'b', linewidth = 3); ax3.set_title('t=20')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Density', fontsize=12)


df = pd.read_fwf('Brio-Wu.block0.out1.00040.tab',skiprows=1)
ax4.plot(df.x1v, df.rho, 'b', linewidth = 3); ax4.set_title('t=40')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Density', fontsize=12)

plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Brio-Wu.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.press, 'g', linewidth = 3); ax1.set_title('t=0'); 
ax1.set_ylabel('Pressure', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00010.tab',skiprows=1)
ax2.plot(df.x1v, df.press, 'g', linewidth = 3); ax2.set_title('t=10')
ax2.set_ylabel('Pressure', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00020.tab',skiprows=1)
ax3.plot(df.x1v, df.press, 'g', linewidth = 3); ax3.set_title('t=20')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Pressure', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00040.tab',skiprows=1)
ax4.plot(df.x1v, df.press, 'g', linewidth = 3); ax4.set_title('t=40')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Pressure', fontsize=12)

plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Brio-Wu.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax1.set_title('t=0')
ax1.set_ylabel('Velocity', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00010.tab',skiprows=1)
ax2.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax2.set_title('t=10')
ax2.set_ylabel('Velocity', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00020.tab',skiprows=1)
ax3.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax3.set_title('t=20')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Velocity', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00040.tab',skiprows=1)
ax4.plot(df.x1v, df.vel1, 'r', linewidth = 3); ax4.set_title('t=40')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Velocity', fontsize=12)

plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

df = pd.read_fwf('Brio-Wu.block0.out1.00000.tab',skiprows=1)
ax1.plot(df.x1v, df.Bcc2, 'm', linewidth = 3); ax1.set_title('t=0')
ax1.set_ylabel('Magnetic Field', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00010.tab',skiprows=1)
ax2.plot(df.x1v, df.Bcc2, 'm', linewidth = 3); ax2.set_title('t=10')
ax2.set_ylabel('Magnetic Field', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00020.tab',skiprows=1)
ax3.plot(df.x1v, df.Bcc2, 'm', linewidth = 3); ax3.set_title('t=20')
ax3.set_xlabel('shock tube', fontsize=12); ax3.set_ylabel('Magnetic Field', fontsize=12)

df = pd.read_fwf('Brio-Wu.block0.out1.00040.tab',skiprows=1)
ax4.plot(df.x1v, df.Bcc2, 'm', linewidth = 3); ax4.set_title('t=40')
ax4.set_xlabel('shock tube', fontsize=12); ax4.set_ylabel('Magnetic Field', fontsize=12)

plt.show()
